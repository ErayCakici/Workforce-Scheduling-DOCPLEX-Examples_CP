# %% [markdown]
# This notebook adresseses an employee scheduling problem involving multiple employees and tasks.
#
# The objective studied is maximizing total number of tasks completed within available times of employees.
#
# Each task can be assigned to at most one employee and preemption is not allowed. The duration of tasks is fixed (independent of the assigned employee) and it is assumed that each task can be assigned to any eligible employee (employees are capable to process tasks based on their skillset). Finally, employees are associated with availability start and end times.
#
# In some scheduling environments **time-lag** constraints can exist which restrict time differences between consecutive operations of a job or consecutive jobs on the same employee or machine. Therefore, this notebook addresses an example time-lag constraint. As an example, it is ensured that minimum difference between end and start times of consecutive tasks on the same employee should be more than a given value (a constraint similar to minimum setup time which keeps employee idle at least for a certain amount of time betweemn consecutive tasks).
#
# The scheduling problem can be also viewed as machine scheduling problem in which employees correspond to machines.

# %%
import pandas as pd
import math
import numpy as np
from collections import namedtuple
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # READ DATA

# %%
employeesTable = pd.read_excel("C:\\Users\\167295724\\Desktop\\EmployeeScheduling\\MasterData.xlsx", sheet_name='Employees', header=0)
employeesTable = employeesTable.head(5) # select only 5 employees in order to have a small-sized problem
employeesTable
# Out:
#        name  availability_start  availability_end  seniority  qualification  \
# 0      Anne                 480              1020         11              1
# 1  Bethanie                 480              1020          4              5
# 2     Betsy                 480              1020          2              2
# 3     Cathy                 480              1020          2              2
# 4   Cecilia                 480              1020          9              5
#
#    pay_rate
# 0        25
# 1        28
# 2        17
# 3        17
# 4        38

# %%
tasksTable = pd.read_excel("C:\\Users\\167295724\\Desktop\\EmployeeScheduling\\MasterData.xlsx", sheet_name='Tasks', header=0)
tasksTable = tasksTable.head(30) # select only 30 tasks in order to have a small-sized problem
tasksTable
# Out:
#    task_id        task_type  task_duration  required_nbr_of_employees
# 0     T001         Oncology            110                          1
# 1     T002     Cardiac Care             80                          1
# 2     T003  Anaesthesiology             60                          1
# 3     T004       Pediatrics             70                          1
# 4     T005         Oncology            120                          1
# 5     T006     Cardiac Care             80                          1
# 6     T007       Pediatrics             80                          1
# 7     T008         Oncology             60                          1
# 8     T009  Anaesthesiology            110                          1
# 9     T010     Cardiac Care             30                          1
# 10    T011       Geriatrics             80                          1
# 11    T012         Oncology             70                          1
# 12    T013         Oncology            110                          1
# 13    T014       Pediatrics            110                          1
# 14    T015       Geriatrics            120                          1
# 15    T016       Geriatrics             70                          1
# 16    T017  Anaesthesiology            100                          1
# 17    T018  Anaesthesiology             90                          1
# 18    T019  Anaesthesiology            120                          2
# 19    T020       Geriatrics             50                          1
# 20    T021         Oncology             80                          1
# 21    T022       Pediatrics             70                          1
# 22    T023  Anaesthesiology             90                          1
# 23    T024       Geriatrics             60                          1
# 24    T025     Cardiac Care            110                          1
# 25    T026         Oncology             60                          2
# 26    T027  Anaesthesiology            110                          1
# 27    T028  Anaesthesiology            110                          1
# 28    T029         Oncology            120                          1
# 29    T030         Oncology             70                          1

# %%
skillsTable = pd.read_excel("C:\\Users\\167295724\\Desktop\\EmployeeScheduling\\MasterData.xlsx", sheet_name='Skills', header=0)
skillsTable
# Out:
#          name       department Eligible?
# 0        Anne  Anaesthesiology        No
# 1    Bethanie  Anaesthesiology       Yes
# 2       Betsy  Anaesthesiology       Yes
# 3       Cathy  Anaesthesiology       Yes
# 4     Cecilia  Anaesthesiology       Yes
# ..        ...              ...       ...
# 155   Roberta       Geriatrics        No
# 156   Suzanne       Geriatrics       Yes
# 157    Vickie       Geriatrics        No
# 158    Wendie       Geriatrics       Yes
# 159       Zoe       Geriatrics       Yes
#
# [160 rows x 3 columns]

# %%
# Create a new dataframe to show compatible employee-task pairs through the Skills Table

# Add a constant column to both DataFrames to perform the cross join
employeesTable['key'] = 1
tasksTable['key'] = 1

# Perform a cross join by merging on the constant column 'key' to list "all" employee-task pairs
cross_joined_df = pd.merge(employeesTable, tasksTable, on='key').drop('key', axis=1)[['name', 'availability_start','availability_end','task_id', 'task_type','task_duration','required_nbr_of_employees']]
employeesTable.drop('key', axis=1, inplace=True)
tasksTable.drop('key', axis=1, inplace=True)
cross_joined_df = cross_joined_df.rename(columns={'task_type': 'department'})
#cross_joined_df

# Create new a table which lists only the tasks that can be processed by corresponding employee among "all" employee-task pairs
employeeTasksTable = pd.merge(cross_joined_df, skillsTable, on=['name', 'department'], how='inner')
employeeTasksTable = employeeTasksTable.sort_values(by=['name', 'task_id'], ascending=[True, True])
employeeTasksTable = employeeTasksTable[employeeTasksTable['Eligible?'] == "Yes"]
employeeTasksTable
# Out:
#         name  availability_start  availability_end task_id       department  \
# 0       Anne                 480              1020    T001         Oncology
# 9       Anne                 480              1020    T002     Cardiac Care
# 1       Anne                 480              1020    T005         Oncology
# 10      Anne                 480              1020    T006     Cardiac Care
# 2       Anne                 480              1020    T008         Oncology
# ..       ...                 ...               ...     ...              ...
# 126  Cecilia                 480              1020    T026         Oncology
# 139  Cecilia                 480              1020    T027  Anaesthesiology
# 140  Cecilia                 480              1020    T028  Anaesthesiology
# 127  Cecilia                 480              1020    T029         Oncology
# 128  Cecilia                 480              1020    T030         Oncology
#
#      task_duration  required_nbr_of_employees Eligible?
# 0              110                          1       Yes
# 9               80                          1       Yes
# 1              120                          1       Yes
# 10              80                          1       Yes
# 2               60                          1       Yes
# ..             ...                        ...       ...
# 126             60                          2       Yes
# 139            110                          1       Yes
# 140            110                          1       Yes
# 127            120                          1       Yes
# 128             70                          1       Yes
#
# [81 rows x 8 columns]

# %% [markdown]
# # PREPARE DATA

# %% [markdown]
# Tuple data type can be used to retrieve certain values of each row of a dataframe (to be used in the optimization model). Each tuple set can correspond to an input table and the pandas method itertuples() returns a named tuple for each row of a DataFrame.

# %%
employeesT  = namedtuple("employeesT",['name', 'availabilityStart', 'availabilityEnd', 'seniority', 'qualification', 'payRate'])
employees  = [employeesT(*employees_row) for employees_row in employeesTable.itertuples(index=False)]
#employees

# %%
tasksT  = namedtuple("tasksT",['taskId', 'taskType', 'taskDuration', 'requiredNbrOfEmployees'])
tasks  = [tasksT(*tasks_row) for tasks_row in tasksTable.itertuples(index=False)]
#tasks

# %%
employeeTasksT  = namedtuple("employeeTasksT",['name', 'availabilityStart', 'availabilityEnd', 'taskId', 'department', 'taskDuration','requiredNbrOfEmployees','eligible'])
employeeTasks  = [employeeTasksT(*employeeTasks_row) for employeeTasks_row in employeeTasksTable.itertuples(index=False)]
#employeeTasks

# %% [markdown]
# # CREATE A MODEL INSTANCE

# %%
from docplex.cp.model import *
mdl = CpoModel(name='employeeScheduling')

# %% [markdown]
# # DEFINE DECISION VARIABLES

# %%
# define  processing interval of each task at each "eligible" employee
employeeTasks_itv_vars = {}   
for et in employeeTasks:
    employeeTasks_itv_vars[et] = mdl.interval_var(start=(et.availabilityStart,et.availabilityEnd), end=(et.availabilityStart,et.availabilityEnd), size=et.taskDuration, optional=True)

# %%
# define sequencing variables for each employee (to be used in no overlap constraint)
sequence_vars = {}  
for e in employees:
    sequence_vars [e] = mdl.sequence_var([employeeTasks_itv_vars[et] for et in employeeTasks if et.name==e.name])

# %% [markdown]
# # EXPRESS OBJECTIVE FUNCTION

# %%
# maximize number of tasks that are completed by an employee
objective = mdl.sum([mdl.presence_of(employeeTasks_itv_vars[et]) for et in employeeTasks])
mdl.add(mdl.maximize(objective))

# %% [markdown]
# # DEFINE CONSTRAINTS

# %%
# each task can be assigned to at most one employee
for t in tasks:
    mdl.add(mdl.sum(mdl.presence_of(employeeTasks_itv_vars[et]) for et in employeeTasks if et.taskId==t.taskId)<=1)

# %%
# no overlap constraint
for e in employees:
    mdl.add(mdl.no_overlap(sequence_vars[e]))

# %%
# timelag constraint
# it is ensured that minimum difference between end and start times of consecutive tasks on the same employee should be more than a given value (a constraint similar to minimum setup time which keeps employee idle at least for a certain amount of time betweemn consecutive tasks).

timelag = 2

for et in employeeTasks:
    for e in employees:
        if et.name==e.name:
            mdl.add(mdl.start_of_next(sequence_vars[e],employeeTasks_itv_vars[et],999999,999999) - mdl.end_of(employeeTasks_itv_vars[et],-999999) >=timelag)

# %% [markdown]
# # SOLVE THE MODEL

# %%
msol=mdl.solve(TimeLimit=60, execfile='C:\\Program Files\\IBM\\ILOG\\CPLEX_Studio221\\cpoptimizer\\bin\\x64_win64\\cpoptimizer.exe')
print("Solution: ")
msol.print_solution()
# Out:
#  ! --------------------------------------------------- CP Optimizer 22.1.0.0 --
#  ! Maximization problem - 86 variables, 116 constraints
#  ! Presolve      : 9 extractables eliminated
#  ! TimeLimit            = 60
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 515.0 (before), 515.0 (after)
#  !  . Memory usage      : 841.0 kB (before), 841.0 kB (after)
#  ! Using parallel search with 8 workers.
#  ! ----------------------------------------------------------------------------
#  !          Best Branches  Non-fixed    W       Branch decision
#                         0         86                 -
#  + New bound is 81
#  ! Using temporal relaxation.
#                         0         86    1            -
#  + New bound is 30
#  *            24       99  0.20s        1      (gap is 25.00%)
#  *            26      246  0.20s        1      (gap is 15.38%)
#  *            27      464  0.20s        1      (gap is 11.11%)
#               27     1000          4    1       908  = startOf(_ITV_60)
#               27     2000          5    1   F          presenceOf(_ITV_11)
#               27     3000          1    1       756 != startOf(_ITV_53)
#  *            28     3214  0.20s        1      (gap is 7.14%)
#  *            29      910  0.20s        2      (gap is 3.45%)
#               29     1000          1    2       776  = startOf(_ITV_15)
#               29     2000          8    2   F         !presenceOf(_ITV_36)
#               29     3000          8    2   F          presenceOf(_ITV_32)
#               29     1000          7    3       816  = startOf(_ITV_27)
#               29     2000          1    3              presenceOf(_ITV_43)
#               29     3000          8    3             !presenceOf(_ITV_77)
#               29     1000          6    4       480  = startOf(_ITV_24)
#               29     2000          6    4             !presenceOf(_ITV_29)
#               29     3000          4    4             !presenceOf(_ITV_74)
#               29     1000          6    5       704  = startOf(_ITV_53)
#  ! Time = 0.20s, Average fail depth = 26, Memory usage = 6.9 MB
#  ! Current bound is 30 (gap is 3.45%)
#  !          Best Branches  Non-fixed    W       Branch decision
#               29     2000          6    5   F          presenceOf(_ITV_35)
#               29     3000          5    5   F          presenceOf(_ITV_72)
#               29     1000          1    6       714  = startOf(_ITV_32)
#               29     2000          7    6             !presenceOf(_ITV_31)
#               29     3000          9    6   F          presenceOf(_ITV_24)
#               29     4000          6    1             !presenceOf(_ITV_58)
#               29     5000          8    1       624 != startOf(_ITV_12)
#               29     6000          9    1   F          presenceOf(_ITV_68)
#               29     7000          7    1             !presenceOf(_ITV_25)
#               29     8000          7    1             !presenceOf(_ITV_76)
#               29     9000          7    1   F          presenceOf(_ITV_58)
#               29    10000          8    1             !presenceOf(_ITV_30)
#               29    11000          6    1   F          presenceOf(_ITV_1)
#               29    12000          7    1             !presenceOf(_ITV_67)
#  ! Using failure-directed search.
#               29    13000          1    1   F          presenceOf(_ITV_78)
#               29     4000          9    2   F          presenceOf(_ITV_38)
#               29     5000          7    2   F          presenceOf(_ITV_50)
#               29     6000          7    2   F          presenceOf(_ITV_31)
#               29     7000          1    2   F   898  = startOf(_ITV_18)
#               29     8000          1    2   F   960  = startOf(_ITV_48)
#  ! Time = 0.29s, Average fail depth = 23, Memory usage = 8.1 MB
#  ! Current bound is 30 (gap is 3.45%)
#  !          Best Branches  Non-fixed    W       Branch decision
#               29     9000          1    2   F   882  = startOf(_ITV_22)
#               29    10000          1    2   F         !presenceOf(_ITV_3)
#               29    11000          1    2   F          presenceOf(_ITV_28)
#               29    12000          1    2   F         !presenceOf(_ITV_71)
#               29    13000          1    2   F         !presenceOf(_ITV_13)
#               29     4000          8    3   F          presenceOf(_ITV_25)
#               29     5000          8    3       806  = startOf(_ITV_45)
#               29     6000          8    3       806  = startOf(_ITV_14)
#               29     7000          8    3   F          presenceOf(_ITV_13)
#               29     8000          8    3       918  = startOf(_ITV_74)
#               29     9000          9    3             !presenceOf(_ITV_42)
#               29    10000          7    3       806  = startOf(_ITV_48)
#               29    11000          7    3       898 != startOf(_ITV_11)
#               29    12000          9    3   F          presenceOf(_ITV_48)
#               29    13000          1    3       592  = startOf(_ITV_18)
#               29    14000          1    3       908  = startOf(_ITV_7)
#               29    15000          1    3   F          presenceOf(_ITV_60)
#               29    16000          1    3   F         !presenceOf(_ITV_4)
#               29     4000          6    4   F          presenceOf(_ITV_13)
#               29     5000          8    4   F          presenceOf(_ITV_77)
#  ! Time = 0.32s, Average fail depth = 23, Memory usage = 8.1 MB
#  ! Current bound is 30 (gap is 3.45%)
#  !          Best Branches  Non-fixed    W       Branch decision
#               29     6000          8    4   F          presenceOf(_ITV_80)
#               29     7000          7    4       888  = startOf(_ITV_58)
#               29     8000          7    4              presenceOf(_ITV_60)
#               29     9000          8    4   F         !presenceOf(_ITV_12)
#               29    10000          8    4   F          presenceOf(_ITV_40)
#               29    11000          7    4             !presenceOf(_ITV_72)
#               29    12000          7    4       898  = startOf(_ITV_46)
#               29    13000          1    4       870  = startOf(_ITV_42)
#               29    14000          1    4       676  = startOf(_ITV_27)
#               29    15000          1    4       604  = startOf(_ITV_74)
#               29    16000          1    4       840  = startOf(_ITV_67)
#               29     4000          5    5   F         !presenceOf(_ITV_54)
#               29     5000         12    5             !presenceOf(_ITV_13)
#               29     6000          9    5   F          presenceOf(_ITV_30)
#               29     7000          7    5       868 != startOf(_ITV_11)
#               29     8000          7    5             !presenceOf(_ITV_30)
#               29     9000          8    5   F         !presenceOf(_ITV_65)
#               29    10000          6    5             !presenceOf(_ITV_42)
#               29    11000          8    5       480  = startOf(_ITV_18)
#               29    12000          8    5       868 != startOf(_ITV_27)
#  ! Time = 0.32s, Average fail depth = 23, Memory usage = 8.1 MB
#  ! Current bound is 30 (gap is 3.45%)
#  !          Best Branches  Non-fixed    W       Branch decision
#               29    13000          1    5   F   930  = startOf(_ITV_6)
#               29    14000          1    5   F   922  = startOf(_ITV_60)
#               29    15000          1    5       512  = startOf(_ITV_5)
#               29    16000          1    5   F         !presenceOf(_ITV_58)
#               29     4000          9    6              presenceOf(_ITV_36)
#               29     5000          8    6       748  = startOf(_ITV_29)
#               29     6000          9    6   F          presenceOf(_ITV_52)
#               29     7000          7    6       950 != startOf(_ITV_5)
#               29     8000          1    6   F   708  = startOf(_ITV_1)
#               29     9000          1    6   F         !presenceOf(_ITV_76)
#               29    10000          1    6   F   898  = startOf(_ITV_18)
#               29    11000          1    6   F          presenceOf(_ITV_43)
#               29    12000          1    6       480  = startOf(_ITV_6)
#               29     1000          1    7       704  = startOf(_ITV_16)
#               29     2000          7    7             !presenceOf(_ITV_58)
#               29     3000          6    7   F         !presenceOf(_ITV_44)
#               29    14000         28    1   F          presenceOf(_ITV_43)
#               29    14000          1    2   F   932  = startOf(_ITV_23)
#               29    15000          1    2       942  = startOf(_ITV_35)
#               29    17000          1    3   F         !presenceOf(_ITV_18)
#  ! Time = 0.38s, Average fail depth = 19, Memory usage = 9.1 MB
#  ! Current bound is 30 (gap is 3.45%)
#  !          Best Branches  Non-fixed    W       Branch decision
#               29    18000          1    3       940 != startOf(_ITV_6)
#               29    17000          1    4   F         !presenceOf(_ITV_27)
#               29    18000          1    4       858 != startOf(_ITV_68)
#               29    17000          1    5       562  = startOf(_ITV_7)
#               29    18000          1    5   F   942  = startOf(_ITV_77)
#               29    13000          1    6   F          presenceOf(_ITV_2)
#               29    14000          1    6   F   930  = startOf(_ITV_6)
#               29    15000          1    6             !presenceOf(_ITV_58)
#               29     4000          4    7       480  = startOf(_ITV_80)
#               29     5000          5    7             !presenceOf(_ITV_38)
#               29     6000          5    7       858  = startOf(_ITV_3)
#               29    15000          1    1       704  = startOf(_ITV_15)
#               29     7000          1    7   F   952  = startOf(_ITV_72)
#               29     1000          2    8       602  = startOf(_ITV_10)
#               29     2000          5    8             !presenceOf(_ITV_56)
#               29     3000          5    8   F         !presenceOf(_ITV_67)
#               29    16000          1    1       602  = startOf(_ITV_35)
#               29    17000          1    1   F   868  = startOf(_ITV_76)
#               29    16000          1    2       766  = startOf(_ITV_21)
#               29    17000          1    2   F         !presenceOf(_ITV_46)
#  ! Time = 0.48s, Average fail depth = 20, Memory usage = 10.2 MB
#  ! Current bound is 30 (gap is 3.45%)
#  !          Best Branches  Non-fixed    W       Branch decision
#               29    19000          1    3   F   940  = startOf(_ITV_6)
#               29    20000          1    3       828 != startOf(_ITV_13)
#               29    21000          1    3   F   890  = startOf(_ITV_42)
#               29    19000          1    4   F   952  = startOf(_ITV_61)
#               29    20000          1    4       880  = startOf(_ITV_76)
#               29    21000          1    4       542  = startOf(_ITV_61)
#               29    19000          1    5   F   892  = startOf(_ITV_67)
#               29    20000          1    5              presenceOf(_ITV_57)
#               29    21000          8    5   F          presenceOf(_ITV_42)
#               29    16000          1    6   F   900  = startOf(_ITV_5)
#               29    17000          1    6       806 != startOf(_ITV_17)
#               29     8000          1    7   F         !presenceOf(_ITV_69)
#               29     9000          1    7       890  = startOf(_ITV_77)
#               29    10000          1    7   F   952  = startOf(_ITV_72)
#               29     4000          6    8             !presenceOf(_ITV_59)
#               29     5000         10    8   F         !presenceOf(_ITV_48)
#               29     6000          8    8             !presenceOf(_ITV_16)
#               29     7000          6    8       798 != startOf(_ITV_56)
#               29     8000          6    8   F         !presenceOf(_ITV_25)
#               29     9000          7    8   F          presenceOf(_ITV_59)
#  ! Time = 0.48s, Average fail depth = 20, Memory usage = 10.2 MB
#  ! Current bound is 30 (gap is 3.45%)
#  !          Best Branches  Non-fixed    W       Branch decision
#               29    18000          1    1              presenceOf(_ITV_36)
#               29    19000          1    1   F          presenceOf(_ITV_68)
#               29    18000          1    2       716  = startOf(_ITV_28)
#               29    19000          1    2   F   900  = startOf(_ITV_56)
#               29    22000          1    3       694  = startOf(_ITV_52)
#               29    23000          1    3       766 != startOf(_ITV_18)
#               29    24000          1    3       786  = startOf(_ITV_6)
#               29    22000          1    4       890 != startOf(_ITV_35)
#               29    23000          1    4       778  = startOf(_ITV_1)
#               29    24000          1    4   F   952  = startOf(_ITV_61)
#               29    22000          1    5   F   892  = startOf(_ITV_80)
#               29    23000          1    5       714  = startOf(_ITV_9)
#               29    24000          1    5   F          presenceOf(_ITV_77)
#               29    18000          1    6   F          presenceOf(_ITV_67)
#               29    19000          1    6   F         !presenceOf(_ITV_16)
#               29    20000          1    6       878  = startOf(_ITV_20)
#               29    11000          1    7             !presenceOf(_ITV_50)
#               29    12000          1    7       806 != startOf(_ITV_16)
#               29    10000         11    8             !presenceOf(_ITV_75)
#               29    11000         18    8   F          presenceOf(_ITV_39)
#  ! Time = 0.56s, Average fail depth = 20, Memory usage = 10.2 MB
#  ! Current bound is 30 (gap is 3.45%)
#  !          Best Branches  Non-fixed    W       Branch decision
#               29    12000          8    8       756 != startOf(_ITV_30)
#               29    13000          5    8       870 != startOf(_ITV_50)
#               29    20000          1    1              presenceOf(_ITV_47)
#               29    21000          1    1       572  = startOf(_ITV_21)
#               29    22000          1    1   F   892  = startOf(_ITV_66)
#               29    20000          1    2   F   970  = startOf(_ITV_48)
#               29    21000          1    2       888  = startOf(_ITV_46)
#               29    25000          1    3   F         !presenceOf(_ITV_61)
#               29    26000          1    3       480  = startOf(_ITV_20)
#               29    25000          1    4       902  = startOf(_ITV_72)
#               29    26000          1    4       768  = startOf(_ITV_24)
#               29    25000          1    5   F          presenceOf(_ITV_71)
#               29    26000          1    5       480  = startOf(_ITV_57)
#               29    27000          1    5       480  = startOf(_ITV_39)
#               29    21000          1    6   F   942  = startOf(_ITV_76)
#               29    22000          1    6   F   942  = startOf(_ITV_76)
#               29    13000          1    7              presenceOf(_ITV_27)
#               29    14000          1    7   F         !presenceOf(_ITV_60)
#               29    15000          1    7       880  = startOf(_ITV_74)
#               29    14000          1    8       480 != startOf(_ITV_19)
#  ! Time = 0.64s, Average fail depth = 20, Memory usage = 10.2 MB
#  ! Current bound is 30 (gap is 3.45%)
#  !          Best Branches  Non-fixed    W       Branch decision
#               29    15000          1    8       816  = startOf(_ITV_19)
#               29    23000          1    1              presenceOf(_ITV_17)
#               29    24000          1    1       614  = startOf(_ITV_66)
#               29    25000          1    1   F   892  = startOf(_ITV_66)
#               29    22000          1    2             !presenceOf(_ITV_19)
#               29    23000          1    2   F         !presenceOf(_ITV_12)
#               29    24000          1    2             !presenceOf(_ITV_43)
#               29    27000          1    3   F          presenceOf(_ITV_8)
#               29    28000          1    3       820  = startOf(_ITV_66)
#               29    29000          1    3   F   890  = startOf(_ITV_24)
#               29    27000          1    4       830  = startOf(_ITV_81)
#               29    28000          1    4   F   932  = startOf(_ITV_60)
#               29    28000          1    5   F   908  = startOf(_ITV_20)
#               29    29000          1    5   F         !presenceOf(_ITV_39)
#               29    30000          1    5       552  = startOf(_ITV_58)
#               29    23000          1    6       602  = startOf(_ITV_53)
#               29    24000          1    6   F   942  = startOf(_ITV_76)
#               29    25000          1    6   F         !presenceOf(_ITV_17)
#               29    16000          1    7       878 != startOf(_ITV_48)
#               29    17000          1    7   F         !presenceOf(_ITV_34)
#  ! Time = 0.71s, Average fail depth = 20, Memory usage = 10.2 MB
#  ! Current bound is 30 (gap is 3.45%)
#  !          Best Branches  Non-fixed    W       Branch decision
#               29    18000          1    7       808  = startOf(_ITV_53)
#               29    16000          1    8       684  = startOf(_ITV_36)
#               29    17000          1    8   F   962  = startOf(_ITV_72)
#               29    26000          1    1       810 != startOf(_ITV_60)
#               29    27000          1    1       582  = startOf(_ITV_21)
#               29    25000          1    2   F   890  = startOf(_ITV_51)
#               29    26000          1    2   F         !presenceOf(_ITV_63)
#               29    27000          1    2       788 != startOf(_ITV_66)
#               29    30000          1    3   F   890  = startOf(_ITV_30)
#               29    31000          1    3       562  = startOf(_ITV_52)
#               29    32000          1    3   F         !presenceOf(_ITV_67)
#               29    29000          1    4   F   930  = startOf(_ITV_6)
#               29    30000          1    4       480  = startOf(_ITV_17)
#               29    31000          1    4       480  = startOf(_ITV_53)
#               29    31000          1    5       858 != startOf(_ITV_13)
#               29    32000          1    5       728  = startOf(_ITV_66)
#               29    26000          1    6       604  = startOf(_ITV_74)
#               29    19000          1    7   F          presenceOf(_ITV_3)
#               29    20000          1    7       714  = startOf(_ITV_19)
#               29    18000          1    8       756  = startOf(_ITV_74)
#  ! Time = 0.78s, Average fail depth = 20, Memory usage = 10.2 MB
#  ! Current bound is 30 (gap is 3.45%)
#  !          Best Branches  Non-fixed    W       Branch decision
#               29    19000          1    8       888 != startOf(_ITV_25)
#               29    20000          1    8       592  = startOf(_ITV_55)
#               29    28000          1    1       868  = startOf(_ITV_51)
#               29    29000          1    1       800 != startOf(_ITV_37)
#               29    30000          1    1   F         !presenceOf(_ITV_74)
#               29    28000          1    2   F   980  = startOf(_ITV_48)
#               29    29000          1    2       592  = startOf(_ITV_21)
#               29    33000          1    3   F   940  = startOf(_ITV_6)
#               29    34000          1    3   F         !presenceOf(_ITV_52)
#               29    32000          1    4   F   902  = startOf(_ITV_65)
#               29    33000          1    4   F   898  = startOf(_ITV_18)
#               29    33000          1    5       676  = startOf(_ITV_50)
#               29    34000          1    5       818 != startOf(_ITV_1)
#               29    35000          1    5   F         !presenceOf(_ITV_42)
#               29    27000          1    6   F   826  = startOf(_ITV_46)
#               29    28000          1    6       840 != startOf(_ITV_10)
#               29    29000          1    6       888 != startOf(_ITV_16)
#               29    30000          1    6       778  = startOf(_ITV_22)
#               29    21000          1    7       870  = startOf(_ITV_28)
#               29    22000          1    7   F   830  = startOf(_ITV_58)
#  ! Time = 0.85s, Average fail depth = 20, Memory usage = 10.2 MB
#  ! Current bound is 30 (gap is 3.45%)
#  !          Best Branches  Non-fixed    W       Branch decision
#               29    23000          1    7       714  = startOf(_ITV_20)
#               29    21000          1    8       480  = startOf(_ITV_27)
#               29    22000          1    8       634  = startOf(_ITV_16)
#               29    31000          1    1              presenceOf(_ITV_9)
#               29    32000          1    1   F   922  = startOf(_ITV_74)
#               29    33000          1    1       480  = startOf(_ITV_25)
#               29    30000          1    2       888 != startOf(_ITV_14)
#               29    31000          1    2   F         !presenceOf(_ITV_74)
#               29    35000          1    3       868  = startOf(_ITV_7)
#               29    36000          1    3       878 != startOf(_ITV_31)
#               29    34000          1    4   F          presenceOf(_ITV_9)
#               29    35000          1    4   F         !presenceOf(_ITV_34)
#               29    36000          1    5       918  = startOf(_ITV_13)
#               29    37000          1    5       594  = startOf(_ITV_44)
#               29    31000          1    6   F   950  = startOf(_ITV_11)
#               29    32000          1    6       624  = startOf(_ITV_31)
#               29    24000          1    7   F         !presenceOf(_ITV_6)
#               29    25000          1    7   F   948  = startOf(_ITV_7)
#               29    26000          1    7       900  = startOf(_ITV_47)
#               29    23000          1    8       542  = startOf(_ITV_36)
#  ! Time = 0.92s, Average fail depth = 20, Memory usage = 10.2 MB
#  ! Current bound is 30 (gap is 3.45%)
#  !          Best Branches  Non-fixed    W       Branch decision
#               29    24000          1    8   F          presenceOf(_ITV_18)
#               29    25000          1    8   F   932  = startOf(_ITV_58)
#               29    34000          1    1       828  = startOf(_ITV_8)
#               29    35000          1    1       818 != startOf(_ITV_47)
#  *            30    35317  0.92s        1      (gap is 0.00%)
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 6 solutions found.
#  ! Best objective         : 30 (optimal - effective tol. is 0)
#  ! Best bound             : 30
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 262389
#  ! Number of fails        : 112825
#  ! Total memory usage     : 10.4 MB (10.4 MB CP Optimizer + 0.1 MB Concert)
#  ! Time spent in solve    : 0.92s (0.92s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 287707.2
#  ! ----------------------------------------------------------------------------
# Solution:
# -------------------------------------------------------------------------------
# Model constraints: 116, variables: integer: 0, interval: 81, sequence: 5
# Solve status: Optimal
# Search status: SearchCompleted, stop cause: SearchHasNotBeenStopped
# Solve time: 0.92 sec
# -------------------------------------------------------------------------------
# Objective values: (30,), bounds: (30,), gaps: (0,)
# Variables:
#    + 86 anonymous variables

# %% [markdown]
# # PREPARE OUTPUT TABLES

# %%
assignmentReport = [(et.name, et.taskId, et.department
                    ,msol.get_var_solution(employeeTasks_itv_vars[et]).get_start(),msol.get_var_solution(employeeTasks_itv_vars[et]).get_end()) 
                       for et in employeeTasks if msol.get_var_solution(employeeTasks_itv_vars[et]).is_present()]
assignmentReport_df = pd.DataFrame(assignmentReport, columns=['Employee', 'Task', 'Type','StartTime','EndTime'])
assignmentReport_df = assignmentReport_df.sort_values(by=['Employee', 'StartTime'], ascending=[True, True])
assignmentReport_df
# Out:
#     Employee  Task             Type  StartTime  EndTime
# 3       Anne  T013         Oncology        480      590
# 0       Anne  T005         Oncology        592      712
# 5       Anne  T029         Oncology        714      834
# 4       Anne  T021         Oncology        836      916
# 2       Anne  T012         Oncology        918      988
# 1       Anne  T010     Cardiac Care        990     1020
# 8   Bethanie  T023  Anaesthesiology        480      570
# 6   Bethanie  T017  Anaesthesiology        572      672
# 10  Bethanie  T028  Anaesthesiology        674      784
# 9   Bethanie  T027  Anaesthesiology        786      896
# 7   Bethanie  T019  Anaesthesiology        898     1018
# 15     Betsy  T016       Geriatrics        480      550
# 13     Betsy  T011       Geriatrics        552      632
# 11     Betsy  T001         Oncology        634      744
# 14     Betsy  T015       Geriatrics        746      866
# 16     Betsy  T030         Oncology        868      938
# 12     Betsy  T008         Oncology        940     1000
# 21     Cathy  T018  Anaesthesiology        480      570
# 20     Cathy  T009  Anaesthesiology        572      682
# 22     Cathy  T025     Cardiac Care        684      794
# 17     Cathy  T002     Cardiac Care        796      876
# 19     Cathy  T006     Cardiac Care        878      958
# 18     Cathy  T003  Anaesthesiology        960     1020
# 28   Cecilia  T024       Geriatrics        480      540
# 23   Cecilia  T004       Pediatrics        542      612
# 24   Cecilia  T007       Pediatrics        614      694
# 25   Cecilia  T014       Pediatrics        696      806
# 27   Cecilia  T022       Pediatrics        808      878
# 29   Cecilia  T026         Oncology        880      940
# 26   Cecilia  T020       Geriatrics        942      992

# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.colors import ListedColormap

# Your data
df = assignmentReport_df

# Automatically define colors for resources using a colormap
cmap = plt.cm.get_cmap('tab10')  # You can choose other colormaps
colors = [cmap(i) for i in range(len(df['Employee'].unique()))]
resource_colors = dict(zip(df['Employee'].unique(), colors))

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the Gantt chart
for i, row in df.iterrows():
    start_time = row['StartTime']
    end_time = row['EndTime']
    task_duration = end_time - start_time
    ax.barh(row['Employee'], task_duration, left=start_time, color=resource_colors[row['Employee']], edgecolor='black', label="EEEE")

# Customize the chart
ax.set_xlabel('Time')
ax.set_ylabel('Employee')
ax.set_title('Schedule')

# Customize legend
legend_labels = [plt.Rectangle((0,0),1,1,fc=resource_colors[resource]) for resource in df['Employee'].unique()]
ax.legend(legend_labels, df['Employee'].unique())

# Add gridlines
ax.grid(axis='x', linestyle='--', alpha=0.6)

plt.show()
